# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(
    r"C:\Users\SudarshanMallea\Desktop\Ecommerce-Analytics-Project\Dataset\Sample - Superstore.csv.csv",
    encoding="cp1252"
)

# %%
fig, ax = plt.subplots(figsize=(16,4))

ax.axis('off')

plt.text(0.05,0.8,f"Sales\n${df['Sales'].sum():,.0f}",fontsize=18)
plt.text(0.30,0.8,f"Profit\n${df['Profit'].sum():,.0f}",fontsize=18)
plt.text(0.55,0.8,f"Orders\n{df['Order ID'].nunique():,}",fontsize=18)
plt.text(0.80,0.8,f"Customers\n{df['Customer ID'].nunique():,}",fontsize=18)

plt.show()
